# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a DataFrame
data = {
    "Human Pancreas": [0.86912, 0.9099, 0.87585, 0.87328, 0.87754, 0.87343, 0.8737, 0.90611, 0.90744, 0.91486],
    "Human PBMC": [0.80501, 0.74534, 0.81021, 0.80911, 0.75019, 0.76891, 0.78489, 0.80643, 0.76689, 0.8107],
    "Human Kidney": [0.73825, 0.73408, 0.76243, 0.74222, 0.75935, 0.71306, 0.72447, 0.73934, 0.73309, 0.74811],
    "Mouse ES": [0.89414, 0.91177, 0.88422, 0.91423, 0.84348, 0.91596, 0.91102, 0.90022, 0.9621, 0.89911],
    "Mouse Hypothalamus": [0.70386, 0.81292, 0.78247, 0.7809, 0.79173, 0.80283, 0.77088, 0.78559, 0.78605, 0.81431],
    "Mouse Kidney": [0.89869, 0.89071, 0.90374, 0.86052, 0.84456, 0.89791, 0.90257, 0.86503, 0.90168, 0.89923]
}
df = pd.DataFrame(data)

# %%
# Plotting boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.ylim(0.5, 1) 
plt.title("Boxplot of Normalized Mutual Information (NMI) Across Different Datasets")
plt.ylabel("NMI")
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(6, 5))

# Select a vibrant color palette
palette = sns.color_palette("Set2", n_colors=len(df.columns))

# Create the boxplot with the selected palette
sns.boxplot(data=df, palette=palette)

# Set the y-axis limits to focus on the area of interest
plt.ylim(0, 1)

# Enhance title and labels with larger fonts and styles
# plt.title("Boxplot of Normalized Mutual Information (NMI) Across Different Datasets", fontsize=16, fontweight='bold')
plt.ylabel("NMI", fontsize=12)
# plt.xlabel("Datasets", fontsize=12)

# Improve grid visibility and aesthetics
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', axis='y')

# Optionally, improve x-tick labels if needed
plt.xticks(rotation=30, fontsize=12)  # Rotate if x labels are crowded or to improve readability

# Save the figure
plt.savefig('/Users/jiayi_liu/Desktop/NMI_Boxplot.png', format='png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
# Update data for ARI values
data_ari = {
    "Human Pancreas": [0.88868, 0.95404, 0.89458, 0.89442, 0.89593, 0.89326, 0.89409, 0.95168, 0.95422, 0.95789],
    "Human PBMC": [0.75560, 0.67692, 0.78755, 0.79846, 0.67711, 0.72196, 0.69966, 0.79527, 0.68753, 0.78378],
    "Human Kidney": [0.63734, 0.58307, 0.61851, 0.59467, 0.64314, 0.57116, 0.57650, 0.60626, 0.62131, 0.62327],
    "Mouse ES": [0.89245, 0.90766, 0.87740, 0.90812, 0.79106, 0.90939, 0.90799, 0.89522, 0.97901, 0.88934],
    "Mouse Hypothalamus": [0.62660, 0.83482, 0.81527, 0.82067, 0.79326, 0.85585, 0.81191, 0.82322, 0.84076, 0.86898],
    "Mouse Kidney": [0.92124, 0.91011, 0.92247, 0.80908, 0.79532, 0.91808, 0.92383, 0.81419, 0.92003, 0.91971]
}
df_ari = pd.DataFrame(data_ari)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(6, 5))

# Select a vibrant color palette
palette = sns.color_palette("Set2", n_colors=len(df.columns))

# Create the boxplot with the selected palette
sns.boxplot(data=df_ari, palette=palette)

# Set the y-axis limits to focus on the area of interest
plt.ylim(0, 1)

# Enhance title and labels with larger fonts and styles
# plt.title("Boxplot of Normalized Mutual Information (NMI) Across Different Datasets", fontsize=16, fontweight='bold')
plt.ylabel("ARI", fontsize=12)
# plt.xlabel("Datasets", fontsize=12)

# Improve grid visibility and aesthetics
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', axis='y')

# Optionally, improve x-tick labels if needed
plt.xticks(rotation=30, fontsize=12)  # Rotate if x labels are crowded or to improve readability

# Save the figure
plt.savefig('/Users/jiayi_liu/Desktop/ARI_Boxplot.png', format='png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
